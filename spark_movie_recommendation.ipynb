# %% [markdown]
# ## Moive Recommendation

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import seaborn as sns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import os
os.environ["PYSPARK_PYTHON"] = "python3"
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--jars /FileStore/tables/elastic/elasticsearch_spark_20_2_11_7_5_1-cdf5c.jar pyspark-shell'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Part1: Data ETL and Exploration

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("moive analysis") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies = spark.read.load("/FileStore/tables/movies.csv", format='csv', header = True)
ratings = spark.read.load("/FileStore/tables/ratings.csv", format='csv', header = True)
links = spark.read.load("/FileStore/tables/links.csv", format='csv', header = True)
tags = spark.read.load("/FileStore/tables/tags.csv", format='csv', header = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(movies.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th></tr></thead><tbody><tr><td>1</td><td>Toy Story (1995)</td><td>Adventure|Animation|Children|Comedy|Fantasy</td></tr><tr><td>2</td><td>Jumanji (1995)</td><td>Adventure|Children|Fantasy</td></tr><tr><td>3</td><td>Grumpier Old Men (1995)</td><td>Comedy|Romance</td></tr><tr><td>4</td><td>Waiting to Exhale (1995)</td><td>Comedy|Drama|Romance</td></tr><tr><td>5</td><td>Father of the Bride Part II (1995)</td><td>Comedy</td></tr></tbody></table></div>

# %%
display(movies.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th></tr></thead><tbody><tr><td>1</td><td>Toy Story (1995)</td><td>Adventure|Animation|Children|Comedy|Fantasy</td></tr><tr><td>2</td><td>Jumanji (1995)</td><td>Adventure|Children|Fantasy</td></tr><tr><td>3</td><td>Grumpier Old Men (1995)</td><td>Comedy|Romance</td></tr><tr><td>4</td><td>Waiting to Exhale (1995)</td><td>Comedy|Drama|Romance</td></tr><tr><td>5</td><td>Father of the Bride Part II (1995)</td><td>Comedy</td></tr></tbody></table></div>

# %%
display(ratings.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>userId</th><th>movieId</th><th>rating</th><th>timestamp</th></tr></thead><tbody><tr><td>count</td><td>27753444</td><td>27753444</td><td>27753444</td><td>27753444</td></tr><tr><td>mean</td><td>141942.01557064414</td><td>18487.99983414671</td><td>3.5304452124932677</td><td>1.1931218549319255E9</td></tr><tr><td>stddev</td><td>81707.400091494</td><td>35102.625247468335</td><td>1.066352750231989</td><td>2.1604822852234188E8</td></tr><tr><td>min</td><td>1</td><td>1</td><td>0.5</td><td>1000000065</td></tr><tr><td>max</td><td>99999</td><td>99999</td><td>5.0</td><td>999999978</td></tr></tbody></table></div>

# %%
# to see if there is null in ratings
ratings.where(ratings['rating'].isNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: 0</div>

# %%
tmp1 = ratings.groupBy("userID").count().toPandas()['count'].min()
tmp2 = ratings.groupBy("movieId").count().toPandas()['count'].min()
print('For the users that rated movies and the movies that were rated:')
print('Minimum number of ratings per user is {}'.format(tmp1))
print('Minimum number of ratings per movie is {}'.format(tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">For the users that rated movies and the movies that were rated:
# Minimum number of ratings per user is 1
# Minimum number of ratings per movie is 1
# </div>

# %%
tmp1 = sum(ratings.groupBy("movieId").count().toPandas()['count'] == 1)
tmp2 = ratings.select('movieId').distinct().count()
print('{} out of {} movies are rated by only one user'.format(tmp1, tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">10155 out of 53889 movies are rated by only one user
# </div>

# %% [markdown]
# ## Spark SQL and OLAP

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies.createOrReplaceTempView('movies')
ratings.createOrReplaceTempView('ratings')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### The number of Users

# %%
num_user = ratings.select('userId').distinct().count()
num_rating = ratings.select('rating').count()
print('number of users are: {}'.format(num_user))
print('total rating number is: {}'.format(num_rating))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">number of users are: 283228
# total rating number is: 27753444
# </div>

# %% [markdown]
# #### The number of Movies

# %%
num_mv = movies.select('movieId').distinct().count()
print('number of Movies are: {}'.format(num_mv))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">number of Movies are: 58098
# </div>

# %% [markdown]
# #### Number of movies rated by users. Also list movies not rated before (for better visualization, only show 15 movies of them).

# %%
# %sql

Select count(distinct movieId) as rated_num
From ratings
Where rating is not null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rated_num</th></tr></thead><tbody><tr><td>53889</td></tr></tbody></table></div>

# %%
# %sql
-- method1 slower

Select distinct movieId, title
From movies
Where movieId not in (Select distinct movieId From ratings Where rating is not null)
Order by movieId
Limit 15
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th></tr></thead><tbody><tr><td>100609</td><td>Fambul Tok (2011)</td></tr><tr><td>100642</td><td>Sunday Lovers (1980)</td></tr><tr><td>101216</td><td>Shadow Boxers (1999)</td></tr><tr><td>101229</td><td>May the Best Man Win (2009)</td></tr><tr><td>101237</td><td>9500 Liberty (2009)</td></tr><tr><td>101369</td><td>Shadow Zone: My Teacher Ate My Homework (1997)</td></tr><tr><td>101391</td><td>Ascent, The (1994)</td></tr><tr><td>101407</td><td>Laffghanistan: Comedy Down Range (2009)</td></tr><tr><td>101437</td><td>Baby Dance, The (1998)</td></tr><tr><td>101441</td><td>Inspectors 2: A Shred of Evidence, The (2000)</td></tr><tr><td>101472</td><td>Brussels Business, The (2012)</td></tr><tr><td>102082</td><td>Always in My Heart (1942)</td></tr><tr><td>102135</td><td>Sadda Haq (2013)</td></tr><tr><td>102150</td><td>Angel from Texas, An (1940)</td></tr><tr><td>102192</td><td>Successful Calamity, A (1932)</td></tr></tbody></table></div>

# %%
# %sql
-- method2 faster

Select distinct m.movieId, title
From movies m
Left Join ratings r on m.movieId=r.movieId
Where r.rating is null
Order by movieId
Limit 15
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th></tr></thead><tbody><tr><td>100609</td><td>Fambul Tok (2011)</td></tr><tr><td>100642</td><td>Sunday Lovers (1980)</td></tr><tr><td>101216</td><td>Shadow Boxers (1999)</td></tr><tr><td>101229</td><td>May the Best Man Win (2009)</td></tr><tr><td>101237</td><td>9500 Liberty (2009)</td></tr><tr><td>101369</td><td>Shadow Zone: My Teacher Ate My Homework (1997)</td></tr><tr><td>101391</td><td>Ascent, The (1994)</td></tr><tr><td>101407</td><td>Laffghanistan: Comedy Down Range (2009)</td></tr><tr><td>101437</td><td>Baby Dance, The (1998)</td></tr><tr><td>101441</td><td>Inspectors 2: A Shred of Evidence, The (2000)</td></tr><tr><td>101472</td><td>Brussels Business, The (2012)</td></tr><tr><td>102082</td><td>Always in My Heart (1942)</td></tr><tr><td>102135</td><td>Sadda Haq (2013)</td></tr><tr><td>102150</td><td>Angel from Texas, An (1940)</td></tr><tr><td>102192</td><td>Successful Calamity, A (1932)</td></tr></tbody></table></div>

# %% [markdown]
# #### conclusion 1
#
# In this dataset, we have 58098 movies, only 53889 of them are rated. There are 4209 of them are not rated by users.

# %% [markdown]
# #### List Movie Genres

# %%
# %sql

Select distinct explode(split(genres,'\\|')) as categories
From movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>categories</th></tr></thead><tbody><tr><td>Crime</td></tr><tr><td>Romance</td></tr><tr><td>Thriller</td></tr><tr><td>Adventure</td></tr><tr><td>Drama</td></tr><tr><td>War</td></tr><tr><td>Documentary</td></tr><tr><td>Fantasy</td></tr><tr><td>Mystery</td></tr><tr><td>Musical</td></tr><tr><td>Animation</td></tr><tr><td>Film-Noir</td></tr><tr><td>(no genres listed)</td></tr><tr><td>IMAX</td></tr><tr><td>Horror</td></tr><tr><td>Western</td></tr><tr><td>Comedy</td></tr><tr><td>Children</td></tr><tr><td>Action</td></tr><tr><td>Sci-Fi</td></tr></tbody></table></div>

# %% [markdown]
# ### Number of movies and average rating for each category

# %%
categories = spark.sql(
                   '''Select cte.category, count(*) as rate_num, avg(rating) as avg_rate
                      From movies m
                      Join
                        (Select movieId, title, explode(split(genres,'\\\\|')) as category
                        From movies) cte
                      on m.movieId=cte.movieId
                      Join ratings r on m.movieId=r.movieId
                      Group by cte.category
                      Order by 2 Desc''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(categories.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>rate_num</th><th>avg_rate</th></tr></thead><tbody><tr><td>Drama</td><td>12191048</td><td>3.6763707271105814</td></tr><tr><td>Comedy</td><td>9999184</td><td>3.419786704595095</td></tr><tr><td>Action</td><td>8214956</td><td>3.4625655329133838</td></tr><tr><td>Thriller</td><td>7489628</td><td>3.5188010672893233</td></tr><tr><td>Adventure</td><td>6452309</td><td>3.5132836167641694</td></tr></tbody></table></div>

# %%
fig, (ax1, ax2) = plt.subplots(figsize=(10,6), ncols=2, constrained_layout=True)
categories_p = categories.toPandas()

xticks = [cate[0] for cate in categories.select("category").collect()]

ax1.plot('category','avg_rate',data=categories_p)
# plt.plot('iter_num','validation_mse',data=categories_p)
ax1.set_xlabel("categories")
ax1.set_xticklabels(xticks,rotation=90)
ax1.set_ylabel("average rating")
ax1.set_title("average rating for each categories", y=1.08)
ax1.legend()

ax2.plot('category','rate_num',data=categories_p)
ax2.set_xlabel("categories")
ax2.set_xticklabels(xticks,rotation=90)
ax2.set_ylabel("rating number")
ax2.set_title("rating number for each categories", y=1.08)
ax2.legend()

display(fig.show())

# %% [markdown]
# #### Conclusion 2
#
# We have 20 categories of movies in the dataset. **Drama**, **Comedy** and **Action** are top 3 categories received most rating (around 10 million) by users. **Drama**, **Crime**, **Mystery**, **War** and **Film-Noir** are categories rated by relatively higher score. The average rating scores for all these categories are between 3.3 and 3.9 (rating in 0-5 range).

# %% [markdown]
# ### Number of each rating score

# %%
# %sql

Select rating, count(*) as num
From ratings
Group by rating
Order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rating</th><th>num</th></tr></thead><tbody><tr><td>0.5</td><td>442388</td></tr><tr><td>1.0</td><td>886233</td></tr><tr><td>1.5</td><td>441354</td></tr><tr><td>2.0</td><td>1850627</td></tr><tr><td>2.5</td><td>1373419</td></tr><tr><td>3.0</td><td>5515668</td></tr><tr><td>3.5</td><td>3404360</td></tr><tr><td>4.0</td><td>7394710</td></tr><tr><td>4.5</td><td>2373550</td></tr><tr><td>5.0</td><td>4071135</td></tr></tbody></table></div>

# %% [markdown]
# ### Top 1000 movies received most rating

# %%
top_rating_num = spark.sql(
                '''Select r.movieId, m.title, sum(case when rating is not null then 1 else 0 end) as rate_num
                From ratings r
                Join movies m on r.movieId=m.movieId
                Group by 1,2
                Order by 3 desc
                Limit 1000''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_movie_year(title):
  matches = re.search("\(\d{4}\)", title)
  if matches:
    group = matches.group()
    year = group[1:-1]
#     start = matches.start()
    title = title[:matches.start()-1]
    return (title, year)
  else:
    return (title, None)
    
get_year = udf(get_movie_year,\
               StructType([StructField("title", StringType(), True),\
                           StructField("release_year", StringType(), True)]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# only show top 15 movies received most rating

# %%
top_rating_num_movies = top_rating_num.select(
                                "movieId", get_year("title").title.alias("title"),\
                                get_year("title").release_year.alias("release_year"),\
                                "rate_num")

display(top_rating_num_movies.head(15))

top_rating_num_movies.createOrReplaceTempView('top_rate_num_movies')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>release_year</th><th>rate_num</th></tr></thead><tbody><tr><td>318</td><td>Shawshank Redemption, The</td><td>1994</td><td>97999</td></tr><tr><td>356</td><td>Forrest Gump</td><td>1994</td><td>97040</td></tr><tr><td>296</td><td>Pulp Fiction</td><td>1994</td><td>92406</td></tr><tr><td>593</td><td>Silence of the Lambs, The</td><td>1991</td><td>87899</td></tr><tr><td>2571</td><td>Matrix, The</td><td>1999</td><td>84545</td></tr><tr><td>260</td><td>Star Wars: Episode IV - A New Hope</td><td>1977</td><td>81815</td></tr><tr><td>480</td><td>Jurassic Park</td><td>1993</td><td>76451</td></tr><tr><td>527</td><td>Schindler's List</td><td>1993</td><td>71516</td></tr><tr><td>110</td><td>Braveheart</td><td>1995</td><td>68803</td></tr><tr><td>1</td><td>Toy Story</td><td>1995</td><td>68469</td></tr><tr><td>1210</td><td>Star Wars: Episode VI - Return of the Jedi</td><td>1983</td><td>66023</td></tr><tr><td>1196</td><td>Star Wars: Episode V - The Empire Strikes Back</td><td>1980</td><td>65822</td></tr><tr><td>2959</td><td>Fight Club</td><td>1999</td><td>65678</td></tr><tr><td>589</td><td>Terminator 2: Judgment Day</td><td>1991</td><td>64258</td></tr><tr><td>1198</td><td>Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)</td><td>1981</td><td>63505</td></tr></tbody></table></div>

# %%
# %sql

Select release_year, count(*) as num_by_year
From top_rate_num_movies
Group by release_year
Order by 2 Desc
Limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>release_year</th><th>num_by_year</th></tr></thead><tbody><tr><td>1995</td><td>68</td></tr><tr><td>1996</td><td>56</td></tr><tr><td>1999</td><td>51</td></tr><tr><td>1994</td><td>50</td></tr><tr><td>2000</td><td>48</td></tr><tr><td>1998</td><td>47</td></tr><tr><td>1997</td><td>41</td></tr><tr><td>2004</td><td>39</td></tr><tr><td>2001</td><td>38</td></tr><tr><td>1993</td><td>38</td></tr></tbody></table></div>

# %%
# %sql

Select (case when release_year<1970 then 'before 1970' when release_year between 1970 and 1979 then '1970s' when release_year between 1980 and 1989 then '1980s' when release_year between 1990 and 1999 then '1990s' when release_year between 2000 and 2009 then '2000s' else 'after 2010' end) as decade, count(*) as num_by_decade
From top_rate_num_movies
Group by 1
Order by 2 Desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decade</th><th>num_by_decade</th></tr></thead><tbody><tr><td>1990s</td><td>413</td></tr><tr><td>2000s</td><td>277</td></tr><tr><td>1980s</td><td>136</td></tr><tr><td>before 1970</td><td>66</td></tr><tr><td>after 2010</td><td>66</td></tr><tr><td>1970s</td><td>42</td></tr></tbody></table></div>

# %% [markdown]
# ### Top 1000 movies with highest average rating (received over 1000 ratings)

# %%
top_avg_rating_movies = spark.sql(
                  '''Select r.movieId, m.title, round(avg(rating), 2) as avg_rate, sum(case when r.rating is not null then 1 else 0 end) as rate_num
                  From ratings r
                  Join movies m on r.movieId=m.movieId
                  Group by 1,2
                  Having sum(case when r.rating is not null then 1 else 0 end)>=1000
                  Order by 3 desc
                  Limit 1000''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# only show top 15 movies get highest average rating

# %%
top_avg_rating_movies = top_avg_rating_movies.select(
                                "movieId", get_year("title").title.alias("title"),\
                                get_year("title").release_year.alias("release_year"),\
                                "avg_rate", "rate_num")

top_avg_rating_movies.createOrReplaceTempView('top_avg_rate_movies')

display(top_avg_rating_movies.head(15))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>release_year</th><th>avg_rate</th><th>rate_num</th></tr></thead><tbody><tr><td>159817</td><td>Planet Earth</td><td>2006</td><td>4.46</td><td>1384</td></tr><tr><td>318</td><td>Shawshank Redemption, The</td><td>1994</td><td>4.42</td><td>97999</td></tr><tr><td>174053</td><td>Black Mirror: White Christmas</td><td>2014</td><td>4.35</td><td>1074</td></tr><tr><td>858</td><td>Godfather, The</td><td>1972</td><td>4.33</td><td>60904</td></tr><tr><td>50</td><td>Usual Suspects, The</td><td>1995</td><td>4.29</td><td>62180</td></tr><tr><td>527</td><td>Schindler's List</td><td>1993</td><td>4.26</td><td>71516</td></tr><tr><td>1221</td><td>Godfather: Part II, The</td><td>1974</td><td>4.26</td><td>38875</td></tr><tr><td>2019</td><td>Seven Samurai (Shichinin no samurai)</td><td>1954</td><td>4.25</td><td>14578</td></tr><tr><td>1203</td><td>12 Angry Men</td><td>1957</td><td>4.24</td><td>17931</td></tr><tr><td>2959</td><td>Fight Club</td><td>1999</td><td>4.23</td><td>65678</td></tr><tr><td>904</td><td>Rear Window</td><td>1954</td><td>4.23</td><td>22264</td></tr><tr><td>1193</td><td>One Flew Over the Cuckoo's Nest</td><td>1975</td><td>4.22</td><td>42181</td></tr><tr><td>912</td><td>Casablanca</td><td>1942</td><td>4.21</td><td>31095</td></tr><tr><td>750</td><td>Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb</td><td>1964</td><td>4.21</td><td>29484</td></tr><tr><td>5618</td><td>Spirited Away (Sen to Chihiro no kamikakushi)</td><td>2001</td><td>4.21</td><td>23227</td></tr></tbody></table></div>

# %%
# %sql

Select (case when release_year<1970 then 'before 1970' when release_year between 1970 and 1979 then '1970s' when release_year between 1980 and 1989 then '1980s' when release_year between 1990 and 1999 then '1990s' when release_year between 2000 and 2009 then '2000s' else 'after 2010' end) as decade, count(*) as num_by_decade, round(sum(avg_rate*rate_num)/sum(rate_num), 2) as avg_score_by_decade
From top_avg_rate_movies
Group by 1
Order by 2 Desc, 3 Desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decade</th><th>num_by_decade</th><th>avg_score_by_decade</th></tr></thead><tbody><tr><td>2000s</td><td>234</td><td>3.92</td></tr><tr><td>before 1970</td><td>218</td><td>4.02</td></tr><tr><td>1990s</td><td>201</td><td>4.0</td></tr><tr><td>after 2010</td><td>138</td><td>3.91</td></tr><tr><td>1980s</td><td>125</td><td>3.96</td></tr><tr><td>1970s</td><td>84</td><td>4.04</td></tr></tbody></table></div>

# %% [markdown]
# #### Conclusion 3
#
# Rating scores are mainly distributed between 3.0 and 5.0.
# The top 3 most popular movies are 'Shawshank Redemption', 'Forrest Gump' and 'Pulp Fiction' which receive more than 90,000 rating.
# 1990s has 413 of top 1000 popular movies (received most rating in this dataset).
# 'Planet Earth', 'Shawshank Redemption' and 'Black Mirror: White Christmas' are the top 3 movies with the highest average rating score around 4.4. While 'Shawshank Redemption', 'The Godfather' and 'The Usual Suspects' are movies both received high number of rating and average rating score. These movies should be recommended to users in general.

# %% [markdown]
# ## Part2: Spark ALS based approach for training model

# %%
from pyspark.ml.recommendation import ALS, ALSModel
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.sql import Row
from pyspark.sql.functions import arrays_zip, col, explode
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ratings = ratings['userId','movieId','rating']

ratings = ratings.withColumn("userId", ratings["userId"].cast(LongType()))
ratings = ratings.withColumn("movieId", ratings["movieId"].cast(LongType()))
ratings = ratings.withColumn("rating", ratings["rating"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Now split the data into training/validation/testing sets using a 6/2/2 ratio. Also split it by a 3/1 ratio to use k-fold cross validation.

# %%
train, test = ratings.randomSplit([0.75,0.25],seed = 42)
training, validation, testing = ratings.randomSplit([0.6, 0.2, 0.2],seed = 40)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print('train size:', train.count())
print('test size:', test.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">train size: 20817599
# test size: 6935845
# </div>

# %% [markdown]
# ### ALS Model Selection and Evaluation

# %% [markdown]
# #### Method 1: use cross-validation

# %%
ranks = [6, 8, 10]
reg_params = [0.05, 0.1, 0.2]
als = ALS(maxIter=10, userCol="userId", itemCol="movieId", ratingCol="rating",
          coldStartStrategy="drop")

paramGrid = ParamGridBuilder() \
          .addGrid(ALS.rank, ranks) \
          .addGrid(ALS.regParam, reg_params) \
          .build()

mse_evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")

CV = CrossValidator(estimator=als,
                   estimatorParamMaps=paramGrid,
                   evaluator=mse_evaluator,
                   numFolds=3)

cvModel = CV.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:791: UserWarning: Can not find mlflow. To enable mlflow logging, install MLflow library from PyPi.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
best_model = cvModel.bestModel
# best_model.rank
best_model.params
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[58]: [Param(parent=&#39;ALS_eea967866f84&#39;, name=&#39;coldStartStrategy&#39;, doc=&#39;strategy for dealing with unknown or new users/items at prediction time. This may be useful in cross-validation or production scenarios, for handling user/item ids the model has not seen in the training data. Supported values: nan,drop.&#39;),
#  Param(parent=&#39;ALS_eea967866f84&#39;, name=&#39;itemCol&#39;, doc=&#39;column name for item ids. Ids must be within the integer value range.&#39;),
#  Param(parent=&#39;ALS_eea967866f84&#39;, name=&#39;predictionCol&#39;, doc=&#39;prediction column name&#39;),
#  Param(parent=&#39;ALS_eea967866f84&#39;, name=&#39;userCol&#39;, doc=&#39;column name for user ids. Ids must be within the integer value range.&#39;)]</div>

# %%
cvmodel_path = '/FileStore/tables/movieLen' + '/best_cvModel'
best_model.save(cvmodel_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# cvmodel_path = '/FileStore/tables/movieLen' + '/best_cvModel'
cv_model = ALSModel.load(cvmodel_path)
cv_model.rank
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: 10</div>

# %% [markdown]
# #### Method 2: use cross-evaluation toolbox

# %%
def train_ALS(train_data, validation_data, num_iters, reg_param, ranks):
    min_error = float('inf')
    best_rank = -1
    best_regularization = 0
    best_model = None
    for rank in ranks:
        for reg in reg_param:
            # write your approach to train ALS model
            # make prediction
            # get the rating result
            # get the RMSE
            als = ALS(rank=rank, maxIter=num_iters, regParam=reg, userCol="userId", itemCol="movieId", ratingCol="rating",
                      coldStartStrategy="drop")
            model = als.fit(train_data)
            predictions = model.transform(validation_data)
            
            evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
            error = evaluator.evaluate(predictions)
            print ('{} latent factors and regularization = {}: validation RMSE is {}'.format(rank, reg, error))
            if error < min_error:
                min_error = error
                best_rank = rank
                best_regularization = reg
                best_model = model
    print ('\nThe best model has {} latent factors and regularization = {}'.format(best_rank, best_regularization))
    return best_model, best_rank, best_regularization
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
num_iterations = 10
ranks = [6, 8, 10, 12, 14]
reg_params = [0.05, 0.1, 0.2, 0.4, 0.8]

import time
start_time = time.time()
final_model, final_rank, final_reg = train_ALS(training, validation, num_iterations, reg_params, ranks)

print ('Total Runtime: {:.2f} seconds'.format(time.time() - start_time))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">6 latent factors and regularization = 0.05: validation RMSE is 0.8270339846917111
# 6 latent factors and regularization = 0.1: validation RMSE is 0.8259783723732318
# 6 latent factors and regularization = 0.2: validation RMSE is 0.865728671966565
# 6 latent factors and regularization = 0.4: validation RMSE is 0.9611198205310132
# 6 latent factors and regularization = 0.8: validation RMSE is 1.184876345583705
# 8 latent factors and regularization = 0.05: validation RMSE is 0.8225150965936567
# 8 latent factors and regularization = 0.1: validation RMSE is 0.8234703478902027
# 8 latent factors and regularization = 0.2: validation RMSE is 0.86647758131085
# 8 latent factors and regularization = 0.4: validation RMSE is 0.9606929629057956
# 8 latent factors and regularization = 0.8: validation RMSE is 1.1848832137336556
# 10 latent factors and regularization = 0.05: validation RMSE is 0.816098608015772
# 10 latent factors and regularization = 0.1: validation RMSE is 0.8175397923503945
# 10 latent factors and regularization = 0.2: validation RMSE is 0.8646292160443473
# 10 latent factors and regularization = 0.4: validation RMSE is 0.9624828164118169
# 10 latent factors and regularization = 0.8: validation RMSE is 1.1848536484547412
# 12 latent factors and regularization = 0.05: validation RMSE is 0.8187615936843773
# 12 latent factors and regularization = 0.1: validation RMSE is 0.8199634536925003
# 12 latent factors and regularization = 0.2: validation RMSE is 0.8658598059752847
# 12 latent factors and regularization = 0.4: validation RMSE is 0.9608932522795528
# 12 latent factors and regularization = 0.8: validation RMSE is 1.1848738607351403
# 14 latent factors and regularization = 0.05: validation RMSE is 0.8160381409737216
# 14 latent factors and regularization = 0.1: validation RMSE is 0.8185922754250311
# 14 latent factors and regularization = 0.2: validation RMSE is 0.8657723480591543
# 14 latent factors and regularization = 0.4: validation RMSE is 0.9611950712362183
# 14 latent factors and regularization = 0.8: validation RMSE is 1.1848696500682194
#
# The best model has 14 latent factors and regularization = 0.05
# Total Runtime: 4823.12 seconds
# </div>

# %% [markdown]
# #### Plot learning rate

# %%
def learning_curve(iter_array, train, validation, rank, reg):
  train_errors, val_errors = [], []
  for iter in iter_array:
    als = ALS(rank=rank, maxIter=iter, regParam=reg, userCol="userId", itemCol="movieId", ratingCol="rating",
                      coldStartStrategy="drop")
    als_model = als.fit(train)
    train_predict = als_model.transform(train)
    val_predict = als_model.transform(validation)
    train_errors.append(mse_evaluator.evaluate(train_predict))
    val_errors.append(mse_evaluator.evaluate(val_predict))
  
  return train_errors, val_errors
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
iter_array = [1, 2, 5, 10]
train_errors, val_errors = learning_curve(iter_array, train, validation, final_rank, final_reg)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def plot_lr_curve(iter_array, train_errors, val_errors):
  # create dataframe
  lst = [iter_array, train_errors, val_errors]
  R = Row('iter_num', 'train_mse', 'validation_mse')
  lr_df = sc.parallelize(R(*r) for r in zip(*lst)).toDF()

  # plot learning curve
  fig, axes = plt.subplots(1,1)
  lr_df_p = lr_df.toPandas()
  plt.plot('iter_num','train_mse',data=lr_df_p)
  plt.plot('iter_num','validation_mse',data=lr_df_p)
  plt.xlabel("num_iteration")
  plt.ylabel("RMSE")
  plt.title("learning curve")
  plt.legend()

  display(fig.show())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plot_lr_curve(iter_array, train_errors, val_errors)

# %%
model_path = '/FileStore/tables/movieLen' + '/bestModel2'
final_model.save(model_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# model_path = '/FileStore/tables/movieLen' + '/bestModel2'
final_model = ALSModel.load(model_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Model testing
# And finally, make a prediction and check the testing error.

# %%
rmse1 = mse_evaluator.evaluate(cv_model.transform(test))
rmse2 = mse_evaluator.evaluate(final_model.transform(testing))
print('test rmse for method 1 is: {}'.format(rmse1))
print('test rmse for method 2 is: {}'.format(rmse2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">test rmse for method 1 is: 0.8159831533875902
# test rmse for method 2 is: 0.816709903665061
# </div>

# %% [markdown]
# ### Apply the model to do recommendation

# %%
rec_to_user = final_model.recommendForAllUsers(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_recommend(recommend_to_user_df):
  recommend = (recommend_to_user_df
        .withColumn("tmp", arrays_zip("recommendations"))
        .withColumn("tmp", explode("tmp"))
        .select("userId", col("tmp.recommendations")['movieId'].alias('movieId'), col("tmp.recommendations")['rating'].alias('rating')))
  return recommend.join(movies, recommend.movieId==movies.movieId).select(recommend.userId, "title", "genres", "rating")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Recommend for all users (10 recommendations per user, only show recommendations to 2 user)

# %%
rec_to_user_df = get_recommend(rec_to_user)
display(rec_to_user_df.head(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>title</th><th>genres</th><th>rating</th></tr></thead><tbody><tr><td>148</td><td>Heroes (2008)</td><td>(no genres listed)</td><td>5.751230239868164</td></tr><tr><td>148</td><td>The War at Home (1979)</td><td>Documentary|War</td><td>5.672374725341797</td></tr><tr><td>148</td><td>Glenn Killing på Berns (1993)</td><td>Comedy</td><td>5.396997928619385</td></tr><tr><td>148</td><td>The Great Piggy Bank Robbery (1946)</td><td>Animation|Children|Comedy</td><td>5.376803398132324</td></tr><tr><td>148</td><td>Rising Place, The (2002)</td><td>Drama</td><td>5.242195129394531</td></tr><tr><td>148</td><td>The Old Gun (1975)</td><td>Drama|Thriller|War</td><td>5.179086685180664</td></tr><tr><td>148</td><td>Ali Baba Bunny (1957)</td><td>Animation|Children|Comedy</td><td>5.108641147613525</td></tr><tr><td>148</td><td>Sharpe's Eagle (1993)</td><td>Action|Adventure|War</td><td>5.011753559112549</td></tr><tr><td>148</td><td>The Yellow Rolls-Royce (1964)</td><td>Comedy|Drama|Romance</td><td>5.000919818878174</td></tr><tr><td>148</td><td>Freedom on My Mind (1994)</td><td>Documentary</td><td>4.993757247924805</td></tr><tr><td>463</td><td>I Can Speak (2017)</td><td>Comedy|Drama</td><td>3.3854594230651855</td></tr><tr><td>463</td><td>Fifi Howls from Happiness (2013)</td><td>Documentary</td><td>3.2775797843933105</td></tr><tr><td>463</td><td>Acéphale (1969)</td><td>(no genres listed)</td><td>3.2685141563415527</td></tr><tr><td>463</td><td>Rammstein: Live aus Berlin (1999)</td><td>(no genres listed)</td><td>3.261296510696411</td></tr><tr><td>463</td><td>They Call Us Misfits (Dom kallar oss mods) (1968)</td><td>Documentary</td><td>3.2527222633361816</td></tr><tr><td>463</td><td>Morgan Murphy: Irish Goodbye (2014)</td><td>Comedy</td><td>3.243448257446289</td></tr><tr><td>463</td><td>Holy Innocents, The (Santos inocentes, Los) (1984)</td><td>Drama</td><td>3.2398853302001953</td></tr><tr><td>463</td><td>Freedom on My Mind (1994)</td><td>Documentary</td><td>3.222745656967163</td></tr><tr><td>463</td><td>Heroes (2008)</td><td>(no genres listed)</td><td>3.2202608585357666</td></tr><tr><td>463</td><td>Judah Friedlander: America Is the Greatest Country in the United States (2017)</td><td>Comedy</td><td>3.2195420265197754</td></tr></tbody></table></div>

# %%
display(rec_to_user_df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>userId</th><th>title</th><th>genres</th><th>rating</th></tr></thead><tbody><tr><td>count</td><td>2798690</td><td>2798690</td><td>2798690</td><td>2798690</td></tr><tr><td>mean</td><td>141630.38205017347</td><td>null</td><td>null</td><td>5.646920058055335</td></tr><tr><td>stddev</td><td>81767.65366554947</td><td>null</td><td>null</td><td>0.8499038642426338</td></tr><tr><td>min</td><td>1</td><td>"""Great Performances"" Cats (1998)"</td><td>(no genres listed)</td><td>0.45407003</td></tr><tr><td>max</td><td>283228</td><td>チェブラーシカ (2010)</td><td>Western</td><td>13.582502</td></tr></tbody></table></div>

# %% [markdown]
# #### Personalized recommendation

# %%
user_subset = ratings.where(ratings.userId == 1)
user_subset_recs = get_recommend(final_model.recommendForUserSubset(user_subset, 10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(user_subset_recs)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>title</th><th>genres</th><th>rating</th></tr></thead><tbody><tr><td>1</td><td>Willie & Phil (1980)</td><td>Comedy|Drama|Romance</td><td>5.9306693</td></tr><tr><td>1</td><td>O Pátio das Cantigas (1942)</td><td>Comedy</td><td>5.832705</td></tr><tr><td>1</td><td>Let's Play Two (2017)</td><td>Documentary</td><td>5.802419</td></tr><tr><td>1</td><td>The State I Am In (2000)</td><td>Drama</td><td>5.708998</td></tr><tr><td>1</td><td>Pearl Jam: Immagine in Cornice - Live in Italy 2006 (2007)</td><td>Documentary|Musical</td><td>5.60396</td></tr><tr><td>1</td><td>What Did You Do in the War, Thanassi? (1971)</td><td>Comedy|Drama</td><td>5.575147</td></tr><tr><td>1</td><td>Ο Θανάσης στη χώρα της σφαλιάρας (1976)</td><td>(no genres listed)</td><td>5.5695586</td></tr><tr><td>1</td><td>Garbage Warrior (2007)</td><td>Documentary</td><td>5.5587406</td></tr><tr><td>1</td><td>Return to Source: The Philosophy of The Matrix (2004)</td><td>Documentary</td><td>5.5492215</td></tr><tr><td>1</td><td>Day of the Wacko (Dzien swira) (2002)</td><td>Comedy|Drama</td><td>5.5443153</td></tr></tbody></table></div>

# %%
# recommend to new users

# 1. Adding the new ratings into the DataFrame (hint: look into using the .union() method)
# 2. Fitting the ALS model
# 3. Make recommendations for the user of choice
# 4. Print out the names of the top $n$ recommendations in a reader-friendly manner


# self_def_user = sc.parallelize([(7654321, 1, 4.0), (7654321, 16, 3.5), (7654321, 40, 4.5), (7654321, 78, 3.5), (7654321, 90, 2.0), 
#                                 (7654321, 100, 1.0), (7654321, 200, 5.0), (7654321, 352, 4.0), (7654321, 508, 4.5), (7654321, 1200, 3.5)]).toDF(("userId", "movieId", "rating"))

# rec_to_self_def_user = get_recommend(final_model.recommendForUserSubset(self_def_user, 2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
